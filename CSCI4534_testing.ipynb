# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import tree
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import time

# %% [markdown]
# # Decision Tree

# %%
#df = pd.read_csv('/content/drive/Shareddrives/434 534 Project/shortNumProcessedData.csv')
'''df = pd.read_csv('shortnumProcessedData.csv')
features = ['Length', 'Protocol']

X = df[features]
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

model = DecisionTreeClassifier(criterion="log_loss", max_depth=None)
model = model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("F1 Score:", metrics.f1_score(y_test, y_pred, average='weighted'))


cm = confusion_matrix(y_test, y_pred)
print(model.n_outputs_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot()

tree.plot_tree(model) #our tree is fucked lol
unique, counts = numpy.unique(y_train, return_counts=True)
dict(zip(unique, counts))'''

#decision tree with info

df = pd.read_csv('shortNumProcessedData.csv')
features = ['Length', 'Protocol', 'Info']

X = df[features]
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

model = DecisionTreeClassifier(criterion="log_loss", max_depth=None)
model = model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("F1 Score:", metrics.f1_score(y_test, y_pred, average='weighted'))


cm = confusion_matrix(y_test, y_pred)
print(model.n_outputs_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap="Blues")

#tree.plot_tree(model)
#unique, counts = numpy.unique(y_train, return_counts=True)
#dict(zip(unique, counts))
# Out:
# Accuracy: 0.7087370242214532
# F1 Score: 0.7049477484471904
# 1

# %%
#without info
''''sc = StandardScaler()
df = pd.read_csv('shortnumProtocolNoInfov2.csv')

df_scaled = sc.fit_transform(df)
# = pd.read_csv('/content/drive/Shareddrives/434 534 Project/shortNumProcessedData.csv')
features = ['Length', 'Protocol']

X = df[features]
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

def accuracy(confusion_matrix):
   diagonal_sum = confusion_matrix.trace()
   sum_of_all_elements = confusion_matrix.sum()
   return diagonal_sum / sum_of_all_elements'''
#with info
sc = StandardScaler()
#df = pd.read_csv('shortNumProcessedData.csv')

df_scaled = sc.fit_transform(df)
# = pd.read_csv('/content/drive/Shareddrives/434 534 Project/shortNumProcessedData.csv')
features = ['Length', 'Protocol', 'Info']

X = df[features]
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

def accuracy(confusion_matrix):
   diagonal_sum = confusion_matrix.trace()
   sum_of_all_elements = confusion_matrix.sum()
   return diagonal_sum / sum_of_all_elements

# %% [markdown]
# # MLP Classifer

# %%
'''#multilayer perceptron classifier

time_start = time.time()
#Initializing the MLPClassifier
classifier = MLPClassifier(hidden_layer_sizes=(300, 250, 200), max_iter=500,activation = 'relu',solver='adam',random_state=1)

classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_pred, y_test)

#Printing the accuracy
time_end = time.time()'''

#MLP with info


#multilayer perceptron classifier

time_start = time.time()
#Initializing the MLPClassifier
classifier = MLPClassifier(hidden_layer_sizes=(300, 250, 200), max_iter=500,activation = 'relu',solver='adam',random_state=1)

classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)

cm = confusion_matrix(y_pred, y_test)

#Printing the accuracy
time_end = time.time()

print("running time of MLP: ", (time_end - time_start)/60.0, "mins")
print("Accuracy of MLPClassifier:", metrics.accuracy_score(y_test, y_pred))
print("F1 Score:", metrics.f1_score(y_test, y_pred, average='weighted'))

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
disp.plot(cmap="Blues")
# Out:
# running time of MLP:  2.455104939142863 mins
# Accuracy of MLPClassifier: 0.5319204152249135
# F1 Score: 0.5268384912524344

# %%
print("running time of MLP: ", (time_end - time_start)/60.0, "mins")
print("Accuracy of MLPClassifier:", metrics.accuracy_score(y_test, y_pred))
print("F1 Score:", metrics.f1_score(y_test, y_pred, average='weighted'))
# Out:
# running time of MLP:  0.3897940476735433 mins
# Accuracy of MLPClassifier: 0.4908524717789023
# F1 Score: 0.46220955304444256

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classifier.classes_)
disp.plot()

# %%
#decision tree individual accuracies by label
a = (1549 / (1549 + 414 + 139 + 875))
b = (2155 / (2155 + 22 + 427 + 285))
c = (2229 / (2229 + 205 + 186 + 340))
d = (2260 / (2260 + 307 + 39 + 128))
print(a)
print(b)
print(c)
print(d)
print((a+b+c+d) / 4)
# Out:
# 0.5203224722875378
# 0.745932848736587
# 0.7530405405405406
# 0.8266276517922458
# 0.7114808783392278

# %% [markdown]
# # K Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
#df = pd.read_csv('shortNumProcessedData.csv')
features = ['Length', 'Protocol', 'Info']

X = df[features]
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
scaler = StandardScaler()
scaler.fit_transform(X_train)
scaler.fit_transform(X_test)
model = KNeighborsClassifier(n_neighbors=100,p=1,weights='distance')
model = model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("F1 Score:", metrics.f1_score(y_test, y_pred, average='weighted'))


cm = confusion_matrix(y_test, y_pred)
#print(model.n_outputs_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap="Blues")

#tree.plot_tree(model)
#unique, counts = numpy.unique(y_train, return_counts=True)
#dict(zip(unique, counts))
# Out:
# Accuracy: 0.7004325259515571
# F1 Score: 0.7015008840237039
